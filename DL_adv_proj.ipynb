# %%
import numpy as np
import shutil
import os
import time
import datetime
import sys
import pathlib
import torch
import torchvision.datasets as datasets
import torchvision.models as models
from torchvision import transforms
from torch import nn
import torch.nn.functional as F
import torch.nn.init as init
import torch.optim as optim
# !pip install torch-ema
from torch_ema import ExponentialMovingAverage
from torch.nn.utils import vector_to_parameters, parameters_to_vector

import random
import json
import matplotlib.pyplot as plt

from tqdm.notebook import tqdm #percentage meter on for-loops

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Collecting torch-ema
#   Downloading torch_ema-0.3-py3-none-any.whl (5.5 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torch-ema) (1.10.0+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->torch-ema) (3.10.0.2)
# Installing collected packages: torch-ema
# Successfully installed torch-ema-0.3
# Thu Dec  9 16:22:32 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8    28W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#symmetric noise - flip 40% of labels randomly 
def symmetric_noise(ds,p=0.4):#this can be done in target transform
  labels = ds.targets
  classes = len(set(labels))
  n_rand_data = int(len(labels)*p)
  rand = np.random.choice(classes, n_rand_data)
  new_labels = np.concatenate((rand,labels[n_rand_data:]))

  new_labels_with_clean_indicator = []
  for nl,l in zip(new_labels,labels):
    if nl==l: new_labels_with_clean_indicator.append([nl,True])
    else: new_labels_with_clean_indicator.append([nl,False])
  #new_ds = torch.utils.data.Subset(ds,np.arange(len(labels))) 
  #makes a copy so we don't change existing dataset, must be a better way
  ds.targets = new_labels_with_clean_indicator
  return ds

#asymmetric noise - flip 40% specific categories
def asymmetric_noise(ds, cifar10=True, p=0.4):
  labels = ds.targets
  noisy_labels = []
  indices = []
  if cifar10:
    for i,label in enumerate(labels):
      flip_bool = random.random() < p
      if label == 9 and flip_bool:
        noisy_labels.append([1, False])
        indices.append(i)
      elif label == 1 and flip_bool:
        noisy_labels.append([9, False])
        indices.append(i)
      elif label == 0 and flip_bool:
        noisy_labels.append([2, False])
        indices.append(i)
      elif label == 2 and flip_bool:
        noisy_labels.append([0, False])
        indices.append(i)
      elif label == 4 and flip_bool:
        noisy_labels.append([7, False])
        indices.append(i)
      elif label == 7 and flip_bool:
        noisy_labels.append([4, False])
        indices.append(i)
      elif label == 3 and flip_bool:
        noisy_labels.append([5, False])
        indices.append(i)
      elif label == 5 and flip_bool:
        noisy_labels.append([3, False])
        indices.append(i)
      else:
        noisy_labels.append([label, True])
  else:
    for label in labels:
      flip_bool = random.random() < p
      if flip_bool:
        noisy_labels.append((target+1)%100)
  #new_ds = torch.utils.data.Subset(ds,np.arange(len(labels)))
  ds.targets = noisy_labels
  return ds



#open set noise - add classes from 
def open_set_noise(ds_cifar10, ds_cifar100, p=0.4):
    new_ds = []
    index1 = np.random.choice(len(ds_cifar10), int(len(ds_cifar10)*p), replace=False)
    index2 = np.random.choice(len(ds_cifar100), int(len(ds_cifar100)*p), replace=False)
    ds_cifar10.data[index1] = ds_cifar100.data[index2]
    for i in range(len(ds_cifar10)):
      if i in index1:
        new_ds.append([ds_cifar10.targets[i], True])
      else:
        new_ds.append([ds_cifar10.targets[i], False])

    ds_cifar10.targets = new_ds
    return new_ds


#instance dependent noise -
def idn_generation(ds,preds_path,p=0.4):#preds is (len(labels),classes)

  #indexed ds: cifar10_train.targets[:20]
  with open(preds_path, 'r') as f:
    preds = np.loadtxt(f)

  labels = ds.targets #assuming [label]
  #get argmax of the ones who aren't correct!
  sorted_preds = preds.argsort() #from small to high
  instance_labels = []
  max_wrong_preds = []

  for i,(label,sorted) in enumerate(zip(labels,sorted_preds)):
    if label==sorted[-1]: 
      instance_labels.append(sorted[-2])
      max_wrong_preds.append(preds[i,sorted[-2]])
    else: 
      instance_labels.append(sorted[-1])
      max_wrong_preds.append(preds[i,sorted[-1]])

  max_wrong_preds = np.argsort(max_wrong_preds)
  n_max_preds = int(p*preds.shape[0])
  idx_of_max = max_wrong_preds[-n_max_preds:]

  new_labels = []
  for idx,label in enumerate(labels):
    if idx in idx_of_max:
      new_labels.append([instance_labels[idx],False])
    else:
      new_labels.append([label,True])


  # for idx in idx_of_max:
  #   labels[idx] = instance_labels[idx]
  ds.targets=new_labels
  #get index of max 40% of maximum predictions, switch those labels in ds.targets, done
  return ds


#index dataset to use for instance dependent noise
def index_ds(ds):
  labels = ds.targets
  new_labels = []
  for i,l in enumerate(labels):
    new_labels.append([l,i])
  #new_ds = torch.utils.data.Subset(ds,np.arange(len(labels))) #makes a copy so we don't change existing dataset, must be a better way
  ds.targets = new_labels  
  return ds

# %%
train_transform = transforms.Compose([
            transforms.RandomCrop(32,padding=4),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
         ])

test_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),

])

cifar10_train = datasets.CIFAR10(train=True,root='/content/cifar10/train',download=True,transform=train_transform)
cifar10_test = datasets.CIFAR10(train=False,root='/content/cifar10/test',download=True,transform=test_transform)

# cifar100_train= datasets.CIFAR100(train=True,root='/content/cifar100/train',download=True,transform=train_transform)
# cifar100_test= datasets.CIFAR100(train=False,root='/content/cifar100/test',download=True,transform=test_transform)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /content/cifar10/train/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting /content/cifar10/train/cifar-10-python.tar.gz to /content/cifar10/train
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /content/cifar10/test/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting /content/cifar10/test/cifar-10-python.tar.gz to /content/cifar10/test

# %% [markdown]
# ##IDN comparison area

# %%
#fetching and creating IDN dataset
idn_path = "/content/gdrive/MyDrive/Colab Notebooks/dl_adv_proj/idx_pred.txt"

idn_ds = idn_generation(cifar10_train,idn_path)

# %%
#their dataset, [true label, noisy label]

og_idn_path = "/content/gdrive/MyDrive/Colab Notebooks/dl_adv_proj/dependent0.4.csv"
og_idn = np.genfromtxt(og_idn_path,delimiter=",")

idn_gen = np.genfromtxt(idn_path)

# %%
og_idn_sum = 0
our_idn_sum= 0
og_vs_our_sum=0
diff_idx = {}
nana = og_idn[0]

diff_plot = []
for idx,(og,idn) in enumerate(zip(og_idn[1:],idn_ds.targets)):
  if og[0]==idn[0]: our_idn_sum+=1
  if og[0]==og[1]: og_idn_sum+=1
  if og[1]==idn[0]:
    og_vs_our_sum+=1
    diff_plot.append(True)
  else: 
    diff_idx[idx]=[og,idn]
    diff_plot.append(False)



print(f'their ratio of noise:{og_idn_sum}, our ratio:{our_idn_sum}, ours vs theirs:{og_vs_our_sum}')
# Out:
# their ratio of noise:30000, our ratio:30000, ours vs theirs:39407

# %%
np.argsort(idn_gen[3933])
# Out:
# array([8, 1, 0, 9, 2, 5, 6, 4, 3, 7])

# %%
idn_gen[3933,3]
# Out:
# 0.06524672259840181

# %%
idn_gen[3933,4]
# Out:
# 0.06078417808212974

# %%
idn_gen[3933,7]
# Out:
# 0.8054707036545016

# %%
diff_idx
# Out:
# {13: [array([2., 2.]), [8, False]],
#  18: [array([2., 3.]), [6, False]],
#  19: [array([6., 1.]), [2, False]],
#  29: [array([0., 8.]), [3, False]],
#  33: [array([3., 3.]), [5, False]],
#  37: [array([7., 5.]), [7, True]],
#  38: [array([3., 8.]), [5, False]],
#  42: [array([2., 0.]), [4, False]],
#  50: [array([9., 0.]), [9, True]],
#  52: [array([7., 7.]), [2, False]],
#  57: [array([2., 0.]), [2, True]],
#  67: [array([9., 8.]), [9, True]],
#  70: [array([5., 3.]), [5, True]],
#  71: [array([9., 1.]), [9, True]],
#  72: [array([6., 9.]), [6, True]],
#  75: [array([1., 1.]), [9, False]],
#  80: [array([3., 0.]), [5, False]],
#  81: [array([5., 2.]), [3, False]],
#  84: [array([7., 4.]), [5, False]],
#  85: [array([7., 2.]), [7, True]],
#  90: [array([2., 6.]), [3, False]],
#  91: [array([3., 3.]), [5, False]],
#  93: [array([0., 0.]), [9, False]],
#  98: [array([4., 4.]), [6, False]],
#  101: [array([3., 3.]), [2, False]],
#  107: [array([5., 7.]), [3, False]],
#  113: [array([7., 2.]), [7, True]],
#  121: [array([2., 2.]), [3, False]],
#  123: [array([2., 2.]), [3, False]],
#  135: [array([8., 0.]), [8, True]],
#  136: [array([1., 9.]), [1, True]],
#  142: [array([3., 2.]), [5, False]],
#  150: [array([3., 3.]), [5, False]],
#  151: [array([6., 8.]), [3, False]],
#  154: [array([6., 4.]), [3, False]],
#  159: [array([3., 5.]), [2, False]],
#  162: [array([4., 5.]), [7, False]],
#  167: [array([5., 3.]), [2, False]],
#  174: [array([3., 6.]), [5, False]],
#  180: [array([4., 4.]), [2, False]],
#  181: [array([7., 7.]), [5, False]],
#  191: [array([7., 8.]), [0, False]],
#  194: [array([2., 2.]), [3, False]],
#  198: [array([5., 5.]), [3, False]],
#  203: [array([3., 3.]), [5, False]],
#  214: [array([9., 9.]), [7, False]],
#  217: [array([5., 5.]), [3, False]],
#  220: [array([0., 8.]), [0, True]],
#  223: [array([0., 9.]), [4, False]],
#  227: [array([1., 9.]), [1, True]],
#  231: [array([6., 8.]), [6, True]],
#  233: [array([0., 1.]), [0, True]],
#  235: [array([6., 6.]), [2, False]],
#  236: [array([1., 9.]), [8, False]],
#  248: [array([6., 9.]), [3, False]],
#  249: [array([6., 0.]), [2, False]],
#  253: [array([3., 3.]), [5, False]],
#  263: [array([4., 7.]), [4, True]],
#  267: [array([7., 4.]), [2, False]],
#  270: [array([9., 1.]), [9, True]],
#  271: [array([2., 2.]), [4, False]],
#  274: [array([9., 9.]), [0, False]],
#  281: [array([2., 2.]), [0, False]],
#  282: [array([1., 1.]), [6, False]],
#  284: [array([0., 8.]), [0, True]],
#  285: [array([5., 0.]), [3, False]],
#  288: [array([2., 4.]), [2, True]],
#  292: [array([6., 0.]), [4, False]],
#  293: [array([0., 9.]), [0, True]],
#  296: [array([4., 0.]), [7, False]],
#  300: [array([2., 0.]), [7, False]],
#  305: [array([5., 7.]), [4, False]],
#  309: [array([8., 9.]), [8, True]],
#  314: [array([3., 3.]), [2, False]],
#  322: [array([9., 9.]), [1, False]],
#  331: [array([3., 5.]), [3, True]],
#  332: [array([0., 0.]), [1, False]],
#  333: [array([3., 6.]), [3, True]],
#  335: [array([2., 5.]), [2, True]],
#  339: [array([5., 7.]), [5, True]],
#  342: [array([3., 4.]), [5, False]],
#  345: [array([4., 3.]), [2, False]],
#  350: [array([6., 3.]), [6, True]],
#  360: [array([9., 1.]), [8, False]],
#  368: [array([6., 3.]), [6, True]],
#  369: [array([9., 9.]), [1, False]],
#  370: [array([3., 2.]), [5, False]],
#  378: [array([4., 7.]), [5, False]],
#  381: [array([4., 4.]), [2, False]],
#  387: [array([6., 4.]), [6, True]],
#  390: [array([4., 0.]), [4, True]],
#  393: [array([1., 9.]), [0, False]],
#  396: [array([1., 8.]), [1, True]],
#  397: [array([8., 9.]), [0, False]],
#  413: [array([7., 7.]), [4, False]],
#  415: [array([0., 9.]), [8, False]],
#  423: [array([2., 2.]), [3, False]],
#  428: [array([9., 9.]), [1, False]],
#  435: [array([4., 7.]), [4, True]],
#  439: [array([0., 3.]), [0, True]],
#  445: [array([3., 3.]), [6, False]],
#  451: [array([6., 3.]), [5, False]],
#  458: [array([4., 0.]), [4, True]],
#  469: [array([7., 7.]), [5, False]],
#  471: [array([5., 5.]), [7, False]],
#  476: [array([3., 7.]), [5, False]],
#  484: [array([4., 4.]), [2, False]],
#  492: [array([7., 7.]), [5, False]],
#  493: [array([1., 6.]), [3, False]],
#  496: [array([8., 1.]), [0, False]],
#  497: [array([0., 2.]), [8, False]],
#  506: [array([1., 8.]), [9, False]],
#  507: [array([8., 1.]), [8, True]],
#  514: [array([7., 7.]), [2, False]],
#  519: [array([8., 0.]), [8, True]],
#  526: [array([4., 4.]), [6, False]],
#  527: [array([0., 8.]), [9, False]],
#  532: [array([6., 6.]), [3, False]],
#  544: [array([2., 3.]), [4, False]],
#  546: [array([8., 9.]), [8, True]],
#  549: [array([4., 5.]), [7, False]],
#  553: [array([9., 8.]), [0, False]],
#  554: [array([8., 0.]), [8, True]],
#  561: [array([1., 1.]), [6, False]],
#  562: [array([8., 0.]), [8, True]],
#  563: [array([4., 4.]), [3, False]],
#  564: [array([0., 8.]), [0, True]],
#  569: [array([5., 5.]), [3, False]],
#  584: [array([8., 1.]), [3, False]],
#  589: [array([7., 6.]), [2, False]],
#  591: [array([6., 8.]), [3, False]],
#  597: [array([3., 3.]), [5, False]],
#  611: [array([7., 9.]), [3, False]],
#  616: [array([4., 0.]), [7, False]],
#  620: [array([6., 2.]), [8, False]],
#  624: [array([5., 3.]), [5, True]],
#  626: [array([0., 8.]), [2, False]],
#  628: [array([0., 8.]), [0, True]],
#  630: [array([2., 3.]), [2, True]],
#  633: [array([6., 2.]), [3, False]],
#  639: [array([3., 0.]), [5, False]],
#  642: [array([4., 4.]), [6, False]],
#  653: [array([5., 6.]), [3, False]],
#  654: [array([7., 7.]), [5, False]],
#  658: [array([0., 0.]), [3, False]],
#  662: [array([7., 4.]), [7, True]],
#  663: [array([0., 8.]), [0, True]],
#  664: [array([9., 3.]), [1, False]],
#  665: [array([4., 4.]), [6, False]],
#  669: [array([4., 0.]), [2, False]],
#  680: [array([6., 1.]), [6, True]],
#  681: [array([5., 3.]), [7, False]],
#  686: [array([5., 7.]), [3, False]],
#  689: [array([2., 5.]), [2, True]],
#  692: [array([6., 2.]), [6, True]],
#  696: [array([2., 2.]), [3, False]],
#  701: [array([2., 2.]), [6, False]],
#  702: [array([3., 6.]), [5, False]],
#  703: [array([9., 3.]), [5, False]],
#  704: [array([8., 9.]), [8, True]],
#  713: [array([0., 0.]), [2, False]],
#  715: [array([8., 8.]), [0, False]],
#  723: [array([8., 9.]), [8, True]],
#  724: [array([2., 2.]), [3, False]],
#  737: [array([2., 2.]), [3, False]],
#  739: [array([7., 7.]), [5, False]],
#  750: [array([5., 7.]), [3, False]],
#  758: [array([4., 3.]), [4, True]],
#  767: [array([5., 3.]), [5, True]],
#  769: [array([9., 1.]), [9, True]],
#  770: [array([6., 8.]), [2, False]],
#  774: [array([3., 4.]), [3, True]],
#  800: [array([2., 6.]), [2, True]],
#  804: [array([2., 4.]), [3, False]],
#  805: [array([3., 6.]), [5, False]],
#  806: [array([3., 3.]), [5, False]],
#  808: [array([2., 2.]), [0, False]],
#  810: [array([2., 5.]), [4, False]],
#  813: [array([5., 6.]), [3, False]],
#  814: [array([5., 3.]), [5, True]],
#  817: [array([5., 5.]), [7, False]],
#  820: [array([2., 6.]), [3, False]],
#  833: [array([1., 1.]), [9, False]],
#  835: [array([1., 1.]), [0, False]],
#  838: [array([6., 6.]), [2, False]],
#  839: [array([5., 5.]), [3, False]],
#  850: [array([3., 5.]), [6, False]],
#  851: [array([5., 5.]), [3, False]],
#  858: [array([7., 5.]), [3, False]],
#  861: [array([3., 3.]), [5, False]],
#  863: [array([6., 6.]), [4, False]],
#  864: [array([2., 0.]), [7, False]],
#  868: [array([4., 3.]), [7, False]],
#  870: [array([8., 0.]), [8, True]],
#  875: [array([5., 5.]), [3, False]],
#  876: [array([4., 4.]), [3, False]],
#  878: [array([3., 1.]), [6, False]],
#  883: [array([9., 8.]), [9, True]],
#  884: [array([9., 9.]), [3, False]],
#  885: [array([2., 2.]), [0, False]],
#  887: [array([4., 2.]), [4, True]],
#  889: [array([2., 0.]), [2, True]],
#  893: [array([1., 9.]), [7, False]],
#  902: [array([0., 0.]), [8, False]],
#  911: [array([0., 3.]), [0, True]],
#  913: [array([7., 0.]), [7, True]],
#  915: [array([9., 9.]), [7, False]],
#  918: [array([5., 2.]), [3, False]],
#  924: [array([2., 2.]), [6, False]],
#  928: [array([5., 0.]), [3, False]],
#  931: [array([6., 4.]), [3, False]],
#  939: [array([4., 4.]), [6, False]],
#  940: [array([0., 0.]), [1, False]],
#  941: [array([3., 6.]), [5, False]],
#  945: [array([4., 0.]), [4, True]],
#  946: [array([4., 0.]), [4, True]],
#  950: [array([9., 9.]), [8, False]],
#  951: [array([4., 7.]), [4, True]],
#  956: [array([7., 7.]), [4, False]],
#  959: [array([4., 7.]), [4, True]],
#  961: [array([6., 2.]), [6, True]],
#  965: [array([0., 0.]), [8, False]],
#  967: [array([8., 8.]), [0, False]],
#  976: [array([4., 4.]), [3, False]],
#  986: [array([2., 6.]), [4, False]],
#  992: [array([3., 6.]), [3, True]],
#  996: [array([5., 2.]), [3, False]],
#  999: [array([5., 5.]), [3, False]],
#  1010: [array([3., 6.]), [5, False]],
#  1013: [array([6., 6.]), [4, False]],
#  1018: [array([4., 7.]), [4, True]],
#  1022: [array([4., 5.]), [7, False]],
#  1026: [array([9., 1.]), [9, True]],
#  1040: [array([2., 1.]), [5, False]],
#  1047: [array([6., 2.]), [6, True]],
#  1050: [array([2., 7.]), [4, False]],
#  1052: [array([1., 9.]), [1, True]],
#  1053: [array([6., 4.]), [2, False]],
#  1057: [array([3., 6.]), [5, False]],
#  1061: [array([5., 7.]), [5, True]],
#  1070: [array([3., 5.]), [2, False]],
#  1080: [array([8., 0.]), [8, True]],
#  1082: [array([9., 9.]), [0, False]],
#  1084: [array([2., 2.]), [5, False]],
#  1085: [array([6., 6.]), [2, False]],
#  1088: [array([5., 5.]), [3, False]],
#  1092: [array([8., 0.]), [8, True]],
#  1122: [array([2., 4.]), [3, False]],
#  1128: [array([3., 3.]), [5, False]],
#  1132: [array([6., 4.]), [6, True]],
#  1138: [array([8., 1.]), [8, True]],
#  1142: [array([0., 7.]), [0, True]],
#  1147: [array([0., 8.]), [0, True]],
#  1154: [array([6., 6.]), [5, False]],
#  1158: [array([4., 0.]), [4, True]],
#  1161: [array([6., 6.]), [2, False]],
#  1164: [array([3., 3.]), [6, False]],
#  1171: [array([9., 1.]), [9, True]],
#  1174: [array([8., 3.]), [6, False]],
#  1176: [array([6., 6.]), [3, False]],
#  1183: [array([8., 0.]), [8, True]],
#  1185: [array([0., 1.]), [0, True]],
#  1187: [array([0., 0.]), [2, False]],
#  1195: [array([0., 8.]), [0, True]],
#  1196: [array([3., 3.]), [6, False]],
#  1200: [array([7., 7.]), [5, False]],
#  1212: [array([4., 2.]), [3, False]],
#  1222: [array([6., 5.]), [6, True]],
#  1232: [array([9., 9.]), [1, False]],
#  1234: [array([0., 8.]), [2, False]],
#  1240: [array([1., 9.]), [1, True]],
#  1241: [array([9., 1.]), [9, True]],
#  1244: [array([5., 3.]), [7, False]],
#  1247: [array([9., 9.]), [1, False]],
#  1250: [array([8., 8.]), [0, False]],
#  1258: [array([2., 2.]), [3, False]],
#  1265: [array([3., 3.]), [4, False]],
#  1268: [array([4., 4.]), [2, False]],
#  1282: [array([8., 0.]), [6, False]],
#  1284: [array([4., 0.]), [4, True]],
#  1285: [array([2., 5.]), [2, True]],
#  1286: [array([3., 3.]), [5, False]],
#  1289: [array([8., 9.]), [0, False]],
#  1290: [array([9., 9.]), [4, False]],
#  1291: [array([2., 7.]), [5, False]],
#  1295: [array([2., 4.]), [2, True]],
#  1296: [array([0., 2.]), [0, True]],
#  1298: [array([5., 3.]), [5, True]],
#  1306: [array([0., 8.]), [0, True]],
#  1308: [array([7., 0.]), [7, True]],
#  1312: [array([4., 7.]), [5, False]],
#  1313: [array([4., 2.]), [4, True]],
#  1314: [array([8., 0.]), [8, True]],
#  1319: [array([0., 8.]), [0, True]],
#  1320: [array([1., 9.]), [6, False]],
#  1324: [array([4., 7.]), [5, False]],
#  1325: [array([8., 9.]), [0, False]],
#  1331: [array([5., 7.]), [3, False]],
#  1333: [array([4., 4.]), [6, False]],
#  1335: [array([0., 8.]), [2, False]],
#  1337: [array([8., 1.]), [0, False]],
#  1338: [array([0., 0.]), [4, False]],
#  1339: [array([4., 7.]), [4, True]],
#  1340: [array([0., 0.]), [2, False]],
#  1342: [array([6., 0.]), [2, False]],
#  1353: [array([9., 1.]), [0, False]],
#  1359: [array([2., 5.]), [2, True]],
#  1364: [array([1., 9.]), [1, True]],
#  1365: [array([7., 7.]), [3, False]],
#  1369: [array([7., 4.]), [7, True]],
#  1371: [array([6., 2.]), [6, True]],
#  1373: [array([4., 6.]), [4, True]],
#  1377: [array([1., 7.]), [3, False]],
#  1381: [array([0., 3.]), [0, True]],
#  1384: [array([9., 9.]), [1, False]],
#  1385: [array([4., 0.]), [4, True]],
#  1402: [array([6., 4.]), [2, False]],
#  1408: [array([1., 9.]), [1, True]],
#  1411: [array([5., 7.]), [3, False]],
#  1412: [array([7., 7.]), [4, False]],
#  1417: [array([5., 7.]), [3, False]],
#  1420: [array([6., 8.]), [3, False]],
#  1424: [array([0., 8.]), [0, True]],
#  1427: [array([3., 6.]), [5, False]],
#  1428: [array([0., 0.]), [2, False]],
#  1431: [array([8., 0.]), [8, True]],
#  1435: [array([4., 7.]), [4, True]],
#  1441: [array([7., 7.]), [4, False]],
#  1444: [array([2., 4.]), [6, False]],
#  1445: [array([7., 7.]), [5, False]],
#  1446: [array([1., 9.]), [1, True]],
#  1449: [array([3., 6.]), [5, False]],
#  1451: [array([4., 5.]), [3, False]],
#  1454: [array([0., 9.]), [1, False]],
#  1456: [array([9., 9.]), [7, False]],
#  1459: [array([7., 7.]), [5, False]],
#  1461: [array([3., 2.]), [3, True]],
#  1469: [array([7., 4.]), [7, True]],
#  1482: [array([5., 3.]), [7, False]],
#  1487: [array([3., 3.]), [5, False]],
#  1488: [array([7., 3.]), [6, False]],
#  1491: [array([4., 7.]), [4, True]],
#  1497: [array([2., 4.]), [2, True]],
#  1499: [array([3., 0.]), [9, False]],
#  1500: [array([2., 4.]), [2, True]],
#  1513: [array([5., 7.]), [2, False]],
#  1516: [array([4., 9.]), [3, False]],
#  1520: [array([1., 8.]), [1, True]],
#  1521: [array([5., 5.]), [2, False]],
#  1532: [array([2., 7.]), [0, False]],
#  1534: [array([3., 6.]), [5, False]],
#  1535: [array([4., 4.]), [6, False]],
#  1536: [array([6., 6.]), [3, False]],
#  1537: [array([6., 6.]), [4, False]],
#  1539: [array([3., 6.]), [5, False]],
#  1542: [array([2., 8.]), [2, True]],
#  1547: [array([1., 1.]), [0, False]],
#  1548: [array([1., 8.]), [5, False]],
#  1554: [array([3., 3.]), [5, False]],
#  1555: [array([3., 6.]), [5, False]],
#  1556: [array([3., 3.]), [5, False]],
#  1557: [array([4., 4.]), [3, False]],
#  1560: [array([0., 8.]), [1, False]],
#  1563: [array([6., 3.]), [6, True]],
#  1574: [array([1., 9.]), [1, True]],
#  1580: [array([5., 3.]), [4, False]],
#  1591: [array([5., 4.]), [3, False]],
#  1598: [array([0., 8.]), [0, True]],
#  1603: [array([3., 0.]), [2, False]],
#  1608: [array([3., 4.]), [5, False]],
#  1610: [array([9., 0.]), [1, False]],
#  1611: [array([1., 9.]), [8, False]],
#  1614: [array([2., 3.]), [2, True]],
#  1615: [array([4., 7.]), [4, True]],
#  1618: [array([5., 4.]), [7, False]],
#  1619: [array([9., 9.]), [1, False]],
#  1625: [array([3., 3.]), [6, False]],
#  1629: [array([0., 8.]), [0, True]],
#  1630: [array([4., 7.]), [5, False]],
#  1631: [array([1., 9.]), [1, True]],
#  1632: [array([0., 8.]), [0, True]],
#  1636: [array([5., 3.]), [5, True]],
#  1641: [array([2., 2.]), [3, False]],
#  1645: [array([7., 7.]), [4, False]],
#  1653: [array([5., 5.]), [3, False]],
#  1663: [array([4., 7.]), [0, False]],
#  1666: [array([4., 2.]), [3, False]],
#  1670: [array([2., 2.]), [4, False]],
#  1692: [array([4., 4.]), [6, False]],
#  1693: [array([2., 7.]), [4, False]],
#  1702: [array([8., 2.]), [8, True]],
#  1710: [array([3., 5.]), [2, False]],
#  1711: [array([0., 0.]), [8, False]],
#  1726: [array([5., 4.]), [8, False]],
#  1727: [array([2., 0.]), [2, True]],
#  1730: [array([6., 3.]), [6, True]],
#  1739: [array([4., 7.]), [0, False]],
#  1740: [array([0., 7.]), [0, True]],
#  1744: [array([9., 9.]), [3, False]],
#  1750: [array([5., 5.]), [3, False]],
#  1753: [array([2., 0.]), [2, True]],
#  1755: [array([0., 3.]), [7, False]],
#  1756: [array([2., 0.]), [6, False]],
#  1759: [array([0., 0.]), [2, False]],
#  1762: [array([4., 7.]), [4, True]],
#  1763: [array([8., 8.]), [0, False]],
#  1767: [array([9., 1.]), [3, False]],
#  1768: [array([2., 0.]), [4, False]],
#  1769: [array([3., 7.]), [5, False]],
#  1773: [array([9., 9.]), [1, False]],
#  1776: [array([7., 5.]), [4, False]],
#  1778: [array([3., 6.]), [5, False]],
#  1779: [array([5., 2.]), [3, False]],
#  1780: [array([5., 2.]), [5, True]],
#  1784: [array([4., 4.]), [3, False]],
#  1789: [array([2., 2.]), [6, False]],
#  1792: [array([2., 2.]), [8, False]],
#  1793: [array([2., 9.]), [1, False]],
#  1799: [array([1., 1.]), [9, False]],
#  1803: [array([3., 3.]), [2, False]],
#  1807: [array([6., 3.]), [4, False]],
#  1815: [array([3., 2.]), [5, False]],
#  1825: [array([7., 7.]), [5, False]],
#  1826: [array([4., 7.]), [4, True]],
#  1828: [array([7., 4.]), [7, True]],
#  1834: [array([3., 3.]), [5, False]],
#  1835: [array([7., 7.]), [5, False]],
#  1836: [array([6., 3.]), [6, True]],
#  1840: [array([7., 4.]), [7, True]],
#  1850: [array([2., 2.]), [3, False]],
#  1851: [array([4., 3.]), [4, True]],
#  1852: [array([2., 2.]), [4, False]],
#  1854: [array([7., 4.]), [7, True]],
#  1856: [array([3., 3.]), [5, False]],
#  1857: [array([7., 7.]), [5, False]],
#  1864: [array([3., 4.]), [2, False]],
#  1880: [array([4., 7.]), [4, True]],
#  1882: [array([4., 0.]), [4, True]],
#  1892: [array([3., 6.]), [3, True]],
#  1893: [array([9., 9.]), [5, False]],
#  1894: [array([7., 4.]), [7, True]],
#  1895: [array([3., 4.]), [3, True]],
#  1913: [array([0., 0.]), [4, False]],
#  1920: [array([8., 9.]), [1, False]],
#  1923: [array([4., 4.]), [2, False]],
#  1932: [array([2., 2.]), [3, False]],
#  1933: [array([6., 1.]), [6, True]],
#  1936: [array([2., 4.]), [0, False]],
#  1938: [array([3., 3.]), [5, False]],
#  1948: [array([6., 6.]), [3, False]],
#  1949: [array([5., 7.]), [3, False]],
#  1952: [array([4., 7.]), [5, False]],
#  1963: [array([3., 3.]), [5, False]],
#  1968: [array([4., 0.]), [6, False]],
#  1969: [array([3., 0.]), [5, False]],
#  1976: [array([5., 8.]), [5, True]],
#  1980: [array([0., 0.]), [2, False]],
#  1988: [array([0., 8.]), [2, False]],
#  1990: [array([2., 0.]), [4, False]],
#  1991: [array([5., 3.]), [5, True]],
#  1992: [array([4., 7.]), [4, True]],
#  2006: [array([0., 8.]), [0, True]],
#  2010: [array([0., 1.]), [8, False]],
#  2013: [array([5., 6.]), [4, False]],
#  2017: [array([5., 5.]), [3, False]],
#  2019: [array([6., 6.]), [3, False]],
#  2022: [array([7., 2.]), [4, False]],
#  2027: [array([0., 8.]), [0, True]],
#  2029: [array([1., 9.]), [1, True]],
#  2032: [array([9., 8.]), [9, True]],
#  2033: [array([2., 4.]), [6, False]],
#  2036: [array([8., 6.]), [8, True]],
#  2040: [array([6., 9.]), [4, False]],
#  2045: [array([7., 3.]), [5, False]],
#  2048: [array([3., 3.]), [5, False]],
#  2051: [array([3., 9.]), [7, False]],
#  2054: [array([5., 5.]), [3, False]],
#  2059: [array([5., 7.]), [3, False]],
#  2060: [array([0., 0.]), [9, False]],
#  2068: [array([3., 0.]), [5, False]],
#  2073: [array([5., 5.]), [3, False]],
#  2083: [array([3., 3.]), [4, False]],
#  2092: [array([3., 0.]), [4, False]],
#  2099: [array([6., 4.]), [6, True]],
#  2101: [array([1., 8.]), [1, True]],
#  2103: [array([7., 0.]), [7, True]],
#  2106: [array([4., 6.]), [4, True]],
#  2114: [array([2., 5.]), [3, False]],
#  2121: [array([2., 2.]), [6, False]],
#  2122: [array([4., 7.]), [4, True]],
#  2123: [array([4., 7.]), [4, True]],
#  2126: [array([2., 4.]), [6, False]],
#  2130: [array([3., 2.]), [4, False]],
#  2131: [array([4., 4.]), [5, False]],
#  2141: [array([3., 5.]), [7, False]],
#  2146: [array([6., 4.]), [6, True]],
#  2147: [array([5., 1.]), [3, False]],
#  2151: [array([7., 5.]), [7, True]],
#  2155: [array([4., 4.]), [2, False]],
#  2157: [array([9., 1.]), [9, True]],
#  2166: [array([8., 0.]), [8, True]],
#  2182: [array([5., 3.]), [5, True]],
#  2183: [array([5., 5.]), [3, False]],
#  2185: [array([1., 9.]), [1, True]],
#  2190: [array([4., 7.]), [4, True]],
#  2191: [array([2., 2.]), [4, False]],
#  2193: [array([2., 2.]), [0, False]],
#  2199: [array([9., 9.]), [8, False]],
#  2200: [array([1., 9.]), [1, True]],
#  2208: [array([9., 8.]), [9, True]],
#  2209: [array([0., 8.]), [0, True]],
#  2212: [array([8., 9.]), [4, False]],
#  2216: [array([4., 4.]), [6, False]],
#  2226: [array([6., 6.]), [2, False]],
#  2232: [array([8., 9.]), [4, False]],
#  2235: [array([4., 5.]), [4, True]],
#  2237: [array([2., 4.]), [2, True]],
#  2242: [array([5., 3.]), [5, True]],
#  2248: [array([0., 7.]), [8, False]],
#  2253: [array([4., 4.]), [6, False]],
#  2265: [array([8., 0.]), [8, True]],
#  2278: [array([7., 7.]), [4, False]],
#  2281: [array([9., 1.]), [9, True]],
#  2285: [array([8., 8.]), [2, False]],
#  2287: [array([0., 1.]), [0, True]],
#  2294: [array([5., 5.]), [7, False]],
#  2297: [array([4., 5.]), [4, True]],
#  2299: [array([6., 6.]), [3, False]],
#  2308: [array([9., 1.]), [0, False]],
#  2310: [array([6., 6.]), [2, False]],
#  2312: [array([3., 4.]), [6, False]],
#  2314: [array([5., 7.]), [5, True]],
#  2317: [array([2., 5.]), [2, True]],
#  2319: [array([7., 7.]), [4, False]],
#  2320: [array([1., 1.]), [9, False]],
#  2326: [array([3., 3.]), [1, False]],
#  2327: [array([4., 2.]), [3, False]],
#  2331: [array([7., 4.]), [7, True]],
#  2336: [array([6., 6.]), [4, False]],
#  2337: [array([3., 3.]), [4, False]],
#  2340: [array([2., 4.]), [6, False]],
#  2341: [array([0., 2.]), [8, False]],
#  2349: [array([2., 0.]), [3, False]],
#  2353: [array([3., 4.]), [5, False]],
#  2354: [array([2., 8.]), [0, False]],
#  2357: [array([9., 9.]), [1, False]],
#  2361: [array([5., 3.]), [4, False]],
#  2370: [array([7., 2.]), [5, False]],
#  2376: [array([3., 3.]), [4, False]],
#  2383: [array([3., 5.]), [3, True]],
#  2387: [array([2., 2.]), [3, False]],
#  2390: [array([1., 1.]), [9, False]],
#  2393: [array([2., 2.]), [6, False]],
#  2398: [array([5., 5.]), [3, False]],
#  2402: [array([4., 4.]), [1, False]],
#  2405: [array([7., 4.]), [3, False]],
#  2410: [array([5., 5.]), [3, False]],
#  2413: [array([0., 1.]), [0, True]],
#  2414: [array([3., 3.]), [5, False]],
#  2417: [array([8., 8.]), [7, False]],
#  2418: [array([4., 7.]), [4, True]],
#  2421: [array([0., 3.]), [2, False]],
#  2427: [array([0., 8.]), [0, True]],
#  2435: [array([0., 6.]), [2, False]],
#  2443: [array([3., 5.]), [2, False]],
#  2445: [array([1., 1.]), [9, False]],
#  2447: [array([3., 3.]), [5, False]],
#  2448: [array([9., 9.]), [1, False]],
#  2457: [array([5., 5.]), [2, False]],
#  2467: [array([2., 0.]), [6, False]],
#  2468: [array([9., 0.]), [1, False]],
#  2476: [array([2., 2.]), [0, False]],
#  2483: [array([8., 9.]), [8, True]],
#  2500: [array([5., 3.]), [5, True]],
#  2504: [array([0., 4.]), [0, True]],
#  2508: [array([9., 9.]), [1, False]],
#  2510: [array([6., 6.]), [3, False]],
#  2513: [array([0., 9.]), [8, False]],
#  2523: [array([8., 1.]), [8, True]],
#  2525: [array([3., 2.]), [5, False]],
#  2537: [array([2., 4.]), [6, False]],
#  2544: [array([4., 7.]), [3, False]],
#  2550: [array([2., 8.]), [2, True]],
#  2551: [array([9., 1.]), [9, True]],
#  2553: [array([7., 7.]), [4, False]],
#  2557: [array([2., 2.]), [6, False]],
#  2558: [array([8., 0.]), [8, True]],
#  2559: [array([3., 3.]), [5, False]],
#  2569: [array([1., 1.]), [9, False]],
#  2581: [array([3., 3.]), [6, False]],
#  2589: [array([2., 2.]), [3, False]],
#  2590: [array([8., 9.]), [0, False]],
#  2601: [array([7., 7.]), [4, False]],
#  2607: [array([6., 4.]), [6, True]],
#  2610: [array([2., 8.]), [2, True]],
#  2613: [array([0., 0.]), [8, False]],
#  2618: [array([6., 5.]), [2, False]],
#  2625: [array([6., 6.]), [3, False]],
#  2629: [array([4., 4.]), [3, False]],
#  2631: [array([6., 3.]), [6, True]],
#  2635: [array([8., 0.]), [8, True]],
#  2637: [array([9., 9.]), [0, False]],
#  2640: [array([8., 1.]), [8, True]],
#  2649: [array([3., 5.]), [6, False]],
#  2654: [array([4., 2.]), [6, False]],
#  2668: [array([3., 0.]), [5, False]],
#  2669: [array([7., 7.]), [5, False]],
#  2680: [array([0., 0.]), [8, False]],
#  2683: [array([0., 0.]), [2, False]],
#  2685: [array([5., 3.]), [5, True]],
#  2694: [array([6., 2.]), [6, True]],
#  2699: [array([3., 6.]), [2, False]],
#  2707: [array([0., 8.]), [0, True]],
#  2708: [array([2., 5.]), [2, True]],
#  2715: [array([7., 0.]), [7, True]],
#  2722: [array([5., 5.]), [3, False]],
#  2724: [array([7., 4.]), [7, True]],
#  2726: [array([5., 5.]), [3, False]],
#  2734: [array([4., 4.]), [2, False]],
#  2736: [array([5., 3.]), [5, True]],
#  2737: [array([2., 2.]), [6, False]],
#  2738: [array([3., 8.]), [6, False]],
#  2742: [array([2., 0.]), [2, True]],
#  2743: [array([8., 0.]), [9, False]],
#  2746: [array([7., 0.]), [7, True]],
#  2750: [array([7., 6.]), [5, False]],
#  2752: [array([1., 1.]), [9, False]],
#  2760: [array([2., 2.]), [0, False]],
#  2773: [array([0., 0.]), [2, False]],
#  2774: [array([6., 1.]), [6, True]],
#  2775: [array([1., 9.]), [1, True]],
#  2777: [array([6., 0.]), [2, False]],
#  2779: [array([4., 7.]), [4, True]],
#  2784: [array([2., 5.]), [3, False]],
#  2785: [array([3., 6.]), [3, True]],
#  2790: [array([7., 4.]), [7, True]],
#  2792: [array([4., 4.]), [6, False]],
#  2795: [array([1., 9.]), [1, True]],
#  2796: [array([6., 3.]), [6, True]],
#  2800: [array([1., 9.]), [1, True]],
#  2809: [array([3., 2.]), [5, False]],
#  2812: [array([2., 2.]), [4, False]],
#  2821: [array([4., 5.]), [4, True]],
#  2848: [array([0., 7.]), [2, False]],
#  2857: [array([8., 9.]), [8, True]],
#  2859: [array([0., 8.]), [2, False]],
#  2860: [array([2., 2.]), [5, False]],
#  2867: [array([2., 3.]), [2, True]],
#  2871: [array([6., 3.]), [6, True]],
#  2877: [array([5., 5.]), [3, False]],
#  2878: [array([2., 2.]), [6, False]],
#  2882: [array([0., 8.]), [0, True]],
#  2891: [array([7., 2.]), [4, False]],
#  2894: [array([2., 2.]), [3, False]],
#  2924: [array([6., 3.]), [6, True]],
#  2926: [array([4., 0.]), [3, False]],
#  2927: [array([2., 0.]), [2, True]],
#  2930: [array([3., 3.]), [5, False]],
#  2934: [array([8., 9.]), [8, True]],
#  2936: [array([2., 3.]), [4, False]],
#  2945: [array([5., 5.]), [3, False]],
#  2947: [array([3., 8.]), [2, False]],
#  2957: [array([2., 5.]), [3, False]],
#  2959: [array([0., 9.]), [0, True]],
#  2962: [array([0., 8.]), [0, True]],
#  2974: [array([8., 1.]), [8, True]],
#  2983: [array([2., 6.]), [4, False]],
#  2984: [array([5., 5.]), [3, False]],
#  2987: [array([8., 8.]), [0, False]],
#  2992: [array([6., 0.]), [2, False]],
#  2995: [array([4., 0.]), [4, True]],
#  2996: [array([0., 3.]), [2, False]],
#  3001: [array([4., 4.]), [2, False]],
#  3002: [array([5., 4.]), [3, False]],
#  3005: [array([5., 3.]), [5, True]],
#  3006: [array([9., 9.]), [8, False]],
#  3009: [array([1., 0.]), [1, True]],
#  3015: [array([5., 5.]), [3, False]],
#  3018: [array([6., 5.]), [3, False]],
#  3019: [array([2., 2.]), [4, False]],
#  3021: [array([5., 7.]), [4, False]],
#  3031: [array([5., 5.]), [3, False]],
#  3033: [array([6., 3.]), [6, True]],
#  3038: [array([8., 1.]), [8, True]],
#  3041: [array([6., 3.]), [5, False]],
#  3042: [array([0., 0.]), [2, False]],
#  3047: [array([5., 5.]), [6, False]],
#  3056: [array([8., 9.]), [0, False]],
#  3057: [array([3., 3.]), [5, False]],
#  3066: [array([0., 8.]), [0, True]],
#  3068: [array([2., 6.]), [3, False]],
#  3086: [array([9., 1.]), [9, True]],
#  3088: [array([9., 0.]), [9, True]],
#  3089: [array([4., 2.]), [5, False]],
#  3091: [array([6., 3.]), [6, True]],
#  3100: [array([3., 0.]), [5, False]],
#  3101: [array([2., 2.]), [5, False]],
#  3103: [array([1., 9.]), [1, True]],
#  3105: [array([3., 2.]), [6, False]],
#  3108: [array([3., 0.]), [5, False]],
#  3110: [array([3., 5.]), [3, True]],
#  3111: [array([6., 3.]), [6, True]],
#  3117: [array([2., 3.]), [2, True]],
#  3119: [array([2., 3.]), [2, True]],
#  3128: [array([0., 0.]), [2, False]],
#  3134: [array([3., 4.]), [5, False]],
#  3135: [array([7., 7.]), [5, False]],
#  3136: [array([0., 1.]), [3, False]],
#  3142: [array([1., 9.]), [1, True]],
#  3150: [array([7., 7.]), [2, False]],
#  3155: [array([8., 8.]), [3, False]],
#  3156: [array([5., 6.]), [3, False]],
#  3170: [array([8., 8.]), [0, False]],
#  3178: [array([3., 6.]), [4, False]],
#  3180: [array([0., 9.]), [0, True]],
#  3182: [array([4., 7.]), [4, True]],
#  3194: [array([3., 6.]), [3, True]],
#  3196: [array([2., 2.]), [6, False]],
#  3204: [array([0., 0.]), [1, False]],
#  3210: [array([2., 2.]), [7, False]],
#  3211: [array([0., 0.]), [9, False]],
#  3216: [array([9., 9.]), [1, False]],
#  3218: [array([3., 6.]), [5, False]],
#  3222: [array([3., 4.]), [6, False]],
#  3224: [array([0., 2.]), [0, True]],
#  3229: [array([5., 3.]), [4, False]],
#  3243: [array([6., 6.]), [4, False]],
#  3244: [array([8., 8.]), [0, False]],
#  3251: [array([7., 4.]), [5, False]],
#  3253: [array([2., 4.]), [2, True]],
#  3255: [array([7., 6.]), [2, False]],
#  3262: [array([6., 4.]), [6, True]],
#  3265: [array([5., 6.]), [3, False]],
#  3268: [array([8., 1.]), [8, True]],
#  3269: [array([8., 9.]), [8, True]],
#  3271: [array([5., 2.]), [5, True]],
#  3277: [array([0., 0.]), [2, False]],
#  3278: [array([5., 3.]), [5, True]],
#  3281: [array([2., 6.]), [2, True]],
#  3286: [array([3., 9.]), [3, True]],
#  3287: [array([3., 3.]), [5, False]],
#  3289: [array([3., 3.]), [4, False]],
#  3295: [array([0., 0.]), [8, False]],
#  3299: [array([2., 6.]), [4, False]],
#  3308: [array([4., 0.]), [4, True]],
#  3310: [array([8., 1.]), [8, True]],
#  3321: [array([2., 0.]), [2, True]],
#  3327: [array([1., 9.]), [3, False]],
#  3335: [array([0., 0.]), [8, False]],
#  3338: [array([2., 4.]), [2, True]],
#  3342: [array([9., 1.]), [9, True]],
#  3346: [array([1., 9.]), [1, True]],
#  3347: [array([0., 8.]), [2, False]],
#  3348: [array([7., 5.]), [2, False]],
#  3349: [array([2., 2.]), [6, False]],
#  3351: [array([3., 8.]), [5, False]],
#  3359: [array([8., 9.]), [0, False]],
#  3362: [array([0., 8.]), [0, True]],
#  3371: [array([3., 6.]), [3, True]],
#  3375: [array([0., 2.]), [0, True]],
#  3382: [array([0., 0.]), [2, False]],
#  3384: [array([8., 8.]), [1, False]],
#  3393: [array([4., 7.]), [4, True]],
#  3396: [array([5., 0.]), [2, False]],
#  3403: [array([6., 5.]), [6, True]],
#  3410: [array([5., 5.]), [3, False]],
#  3413: [array([7., 3.]), [2, False]],
#  3417: [array([2., 2.]), [4, False]],
#  3427: [array([7., 7.]), [4, False]],
#  3428: [array([2., 7.]), [5, False]],
#  3429: [array([3., 9.]), [6, False]],
#  3438: [array([0., 0.]), [2, False]],
#  3445: [array([4., 7.]), [4, True]],
#  3447: [array([3., 3.]), [5, False]],
#  3451: [array([5., 3.]), [7, False]],
#  3457: [array([3., 1.]), [5, False]],
#  3458: [array([6., 5.]), [3, False]],
#  3462: [array([2., 0.]), [2, True]],
#  3466: [array([0., 8.]), [0, True]],
#  3475: [array([3., 7.]), [5, False]],
#  3495: [array([5., 5.]), [3, False]],
#  3499: [array([5., 5.]), [4, False]],
#  3506: [array([2., 2.]), [6, False]],
#  3508: [array([2., 2.]), [3, False]],
#  3509: [array([4., 8.]), [3, False]],
#  3515: [array([0., 0.]), [2, False]],
#  3517: [array([2., 5.]), [4, False]],
#  3520: [array([2., 5.]), [2, True]],
#  3522: [array([4., 4.]), [2, False]],
#  3523: [array([1., 8.]), [1, True]],
#  3524: [array([3., 3.]), [4, False]],
#  3525: [array([6., 5.]), [3, False]],
#  3532: [array([6., 8.]), [4, False]],
#  3538: [array([4., 4.]), [2, False]],
#  3550: [array([3., 6.]), [2, False]],
#  3552: [array([3., 6.]), [3, True]],
#  3560: [array([4., 4.]), [5, False]],
#  3561: [array([8., 8.]), [1, False]],
#  3574: [array([0., 0.]), [2, False]],
#  3575: [array([3., 3.]), [5, False]],
#  3579: [array([8., 0.]), [8, True]],
#  3583: [array([2., 2.]), [4, False]],
#  3587: [array([4., 5.]), [3, False]],
#  3590: [array([6., 7.]), [2, False]],
#  3592: [array([7., 3.]), [2, False]],
#  3593: [array([6., 3.]), [6, True]],
#  3597: [array([9., 9.]), [3, False]],
#  3599: [array([4., 7.]), [4, True]],
#  3607: [array([0., 9.]), [0, True]],
#  3612: [array([4., 0.]), [4, True]],
#  3615: [array([3., 1.]), [5, False]],
#  3616: [array([5., 5.]), [3, False]],
#  3618: [array([0., 8.]), [1, False]],
#  3628: [array([9., 8.]), [1, False]],
#  3629: [array([2., 0.]), [8, False]],
#  3632: [array([5., 4.]), [3, False]],
#  3633: [array([9., 9.]), [0, False]],
#  3636: [array([6., 0.]), [3, False]],
#  3637: [array([7., 0.]), [7, True]],
#  3642: [array([8., 9.]), [8, True]],
#  3649: [array([7., 7.]), [4, False]],
#  3660: [array([5., 9.]), [5, True]],
#  3662: [array([2., 7.]), [5, False]],
#  3664: [array([4., 6.]), [2, False]],
#  3667: [array([5., 5.]), [3, False]],
#  3668: [array([4., 6.]), [4, True]],
#  3678: [array([1., 1.]), [9, False]],
#  3685: [array([9., 9.]), [1, False]],
#  3698: [array([6., 3.]), [6, True]],
#  3714: [array([5., 5.]), [3, False]],
#  3715: [array([7., 0.]), [7, True]],
#  3717: [array([4., 2.]), [7, False]],
#  3720: [array([8., 8.]), [9, False]],
#  3721: [array([0., 9.]), [0, True]],
#  3722: [array([9., 1.]), [9, True]],
#  3723: [array([4., 0.]), [7, False]],
#  3725: [array([0., 8.]), [0, True]],
#  3749: [array([3., 5.]), [3, True]],
#  3753: [array([8., 1.]), [8, True]],
#  3758: [array([3., 3.]), [6, False]],
#  3762: [array([3., 3.]), [2, False]],
#  3770: [array([8., 8.]), [0, False]],
#  3771: [array([2., 0.]), [2, True]],
#  3776: [array([4., 4.]), [6, False]],
#  3777: [array([8., 0.]), [8, True]],
#  3787: [array([3., 5.]), [2, False]],
#  3792: [array([3., 9.]), [5, False]],
#  3803: [array([5., 2.]), [3, False]],
#  3810: [array([5., 2.]), [7, False]],
#  3813: [array([3., 2.]), [6, False]],
#  3816: [array([4., 4.]), [2, False]],
#  3835: [array([7., 4.]), [7, True]],
#  3845: [array([2., 2.]), [4, False]],
#  3850: [array([9., 9.]), [7, False]],
#  3863: [array([3., 5.]), [6, False]],
#  3867: [array([5., 5.]), [3, False]],
#  3868: [array([4., 6.]), [7, False]],
#  3869: [array([2., 0.]), [2, True]],
#  3870: [array([3., 6.]), [2, False]],
#  3879: [array([4., 2.]), [7, False]],
#  3880: [array([0., 0.]), [2, False]],
#  3881: [array([8., 0.]), [8, True]],
#  3884: [array([0., 9.]), [0, True]],
#  3885: [array([8., 8.]), [1, False]],
#  3890: [array([7., 5.]), [3, False]],
#  3900: [array([0., 0.]), [2, False]],
#  3905: [array([3., 3.]), [5, False]],
#  3914: [array([7., 7.]), [6, False]],
#  3916: [array([5., 2.]), [3, False]],
#  3918: [array([0., 8.]), [0, True]],
#  3919: [array([4., 4.]), [7, False]],
#  3920: [array([7., 4.]), [5, False]],
#  3921: [array([9., 8.]), [9, True]],
#  3925: [array([4., 5.]), [4, True]],
#  3926: [array([6., 6.]), [2, False]],
#  3930: [array([9., 0.]), [9, True]],
#  3933: [array([7., 4.]), [3, False]],
#  3940: [array([0., 9.]), [2, False]],
#  3950: [array([8., 1.]), [0, False]],
#  3956: [array([3., 3.]), [5, False]],
#  3961: [array([2., 8.]), [2, True]],
#  3981: [array([4., 7.]), [5, False]],
#  3998: [array([8., 8.]), [0, False]],
#  4000: [array([5., 5.]), [3, False]],
#  4001: [array([8., 1.]), [8, True]],
#  4002: [array([5., 3.]), [5, True]],
#  4004: [array([5., 6.]), [5, True]],
#  4007: [array([3., 8.]), [2, False]],
#  4010: [array([3., 3.]), [5, False]],
#  4012: [array([2., 3.]), [5, False]],
#  4015: [array([6., 3.]), [4, False]],
#  4017: [array([2., 5.]), [2, True]],
#  4026: [array([6., 4.]), [6, True]],
#  4027: [array([0., 0.]), [7, False]],
#  4031: [array([6., 1.]), [2, False]],
#  4034: [array([2., 3.]), [2, True]],
#  4035: [array([6., 1.]), [6, True]],
#  4042: [array([5., 3.]), [5, True]],
#  4043: [array([4., 7.]), [4, True]],
#  4044: [array([5., 5.]), [3, False]],
#  4055: [array([4., 7.]), [6, False]],
#  4058: [array([4., 7.]), [3, False]],
#  4060: [array([0., 9.]), [0, True]],
#  4061: [array([0., 8.]), [0, True]],
#  4062: [array([6., 1.]), [2, False]],
#  4064: [array([6., 4.]), [2, False]],
#  4065: [array([7., 3.]), [7, True]],
#  4073: [array([3., 3.]), [2, False]],
#  4079: [array([0., 4.]), [2, False]],
#  4081: [array([0., 2.]), [4, False]],
#  4085: [array([2., 2.]), [6, False]],
#  4088: [array([7., 7.]), [4, False]],
#  4099: [array([1., 9.]), [1, True]],
#  4103: [array([4., 4.]), [6, False]],
#  4104: [array([4., 2.]), [4, True]],
#  4110: [array([3., 5.]), [8, False]],
#  4118: [array([6., 5.]), [3, False]],
#  4120: [array([5., 5.]), [3, False]],
#  4121: [array([9., 1.]), [9, True]],
#  4122: [array([2., 2.]), [6, False]],
#  4126: [array([6., 3.]), [6, True]],
#  4127: [array([5., 5.]), [3, False]],
#  4128: [array([3., 6.]), [5, False]],
#  4129: [array([4., 0.]), [2, False]],
#  4134: [array([7., 7.]), [4, False]],
#  4137: [array([4., 2.]), [4, True]],
#  4143: [array([6., 5.]), [4, False]],
#  4144: [array([6., 2.]), [6, True]],
#  4149: [array([3., 3.]), [5, False]],
#  4150: [array([9., 8.]), [9, True]],
#  4156: [array([4., 3.]), [4, True]],
#  4163: [array([0., 8.]), [1, False]],
#  4166: [array([3., 6.]), [5, False]],
#  4167: [array([6., 2.]), [4, False]],
#  4168: [array([2., 3.]), [2, True]],
#  4169: [array([9., 1.]), [9, True]],
#  4172: [array([1., 3.]), [1, True]],
#  4179: [array([3., 2.]), [5, False]],
#  4181: [array([6., 3.]), [6, True]],
#  4182: [array([4., 2.]), [4, True]],
#  4186: [array([2., 3.]), [2, True]],
#  4189: [array([2., 2.]), [4, False]],
#  4193: [array([4., 3.]), [4, True]],
#  4199: [array([4., 5.]), [4, True]],
#  4206: [array([1., 1.]), [9, False]],
#  4211: [array([2., 2.]), [4, False]],
#  4212: [array([4., 7.]), [4, True]],
#  4217: [array([6., 2.]), [6, True]],
#  4221: [array([3., 3.]), [2, False]],
#  4223: [array([9., 1.]), [9, True]],
#  4241: [array([7., 7.]), [9, False]],
#  4244: [array([1., 9.]), [1, True]],
#  4251: [array([7., 9.]), [7, True]],
#  4259: [array([5., 7.]), [3, False]],
#  4266: [array([3., 3.]), [5, False]],
#  4267: [array([6., 1.]), [6, True]],
#  4277: [array([8., 0.]), [8, True]],
#  4286: [array([4., 4.]), [0, False]],
#  4301: [array([4., 5.]), [4, True]],
#  4303: [array([8., 0.]), [8, True]],
#  4304: [array([8., 1.]), [8, True]],
#  4305: [array([4., 4.]), [6, False]],
#  4308: [array([3., 9.]), [0, False]],
#  4319: [array([5., 2.]), [3, False]],
#  4322: [array([0., 6.]), [2, False]],
#  4323: [array([4., 7.]), [3, False]],
#  4326: [array([1., 1.]), [8, False]],
#  4327: [array([1., 0.]), [1, True]],
#  4328: [array([4., 8.]), [4, True]],
#  4332: [array([1., 1.]), [8, False]],
#  4340: [array([9., 9.]), [1, False]],
#  4343: [array([8., 0.]), [9, False]],
#  4345: [array([9., 8.]), [0, False]],
#  4349: [array([3., 3.]), [5, False]],
#  4361: [array([3., 3.]), [2, False]],
#  4365: [array([8., 8.]), [3, False]],
#  4369: [array([7., 3.]), [6, False]],
#  4373: [array([0., 8.]), [0, True]],
#  4380: [array([8., 8.]), [2, False]],
#  4384: [array([4., 4.]), [6, False]],
#  4387: [array([0., 8.]), [0, True]],
#  4390: [array([1., 1.]), [9, False]],
#  4392: [array([3., 4.]), [3, True]],
#  4398: [array([2., 8.]), [2, True]],
#  4400: [array([4., 7.]), [4, True]],
#  4404: [array([6., 6.]), [3, False]],
#  4409: [array([6., 6.]), [1, False]],
#  4418: [array([2., 2.]), [0, False]],
#  4420: [array([0., 0.]), [8, False]],
#  4433: [array([7., 7.]), [5, False]],
#  4434: [array([6., 2.]), [4, False]],
#  4441: [array([7., 4.]), [5, False]],
#  4447: [array([4., 7.]), [4, True]],
#  4448: [array([5., 4.]), [3, False]],
#  4455: [array([2., 2.]), [0, False]],
#  4456: [array([5., 7.]), [3, False]],
#  4458: [array([1., 1.]), [0, False]],
#  4476: [array([0., 4.]), [0, True]],
#  4482: [array([2., 2.]), [6, False]],
#  4483: [array([3., 0.]), [6, False]],
#  ...}

# %% [markdown]
# Change what sort of dataset to use here

# %%
batch_size = 128
num_workers = 2

#TODO: add clothing1M dataset if necessary

cifar10_train =  symmetric_noise(cifar10_train)

c10_train_dl = torch.utils.data.DataLoader(cifar10_train,
                                          batch_size=batch_size,
                                          shuffle=True,
                                          num_workers=num_workers)


c10_test_dl = torch.utils.data.DataLoader(cifar10_test,
                                          batch_size=batch_size,
                                          shuffle=False,
                                          num_workers=num_workers)


# c100_train_dl = torch.utils.data.DataLoader(cifar100_train,
#                                           batch_size=batch_size,
#                                           shuffle=True,
#                                           num_workers=num_workers)


# c100_test_dl = torch.utils.data.DataLoader(cifar10_test,
#                                           batch_size=batch_size,
#                                           shuffle=False,
#                                           num_workers=num_workers)

# %%
#EQ1: add noise to gradients
def loss_eq1(output, target, sigma=0.5):
  grad = torch.mean(torch.sum(F.log_softmax(output, dim=1)*target, dim=1))
  grad += sigma*torch.randn(grad.size()).cuda()
  return -grad

#EQ2: add noise to gradients w.r.t. model output
def loss_eq2():
  return True

#EQ3: add noise to one-hot labels
def loss_eq3(output, target, sigma=0.5):
  target += sigma*torch.randn(target.size()).cuda()
  grad = torch.mean(torch.sum(F.log_softmax(output, dim=1)*target, dim=1))
  return -grad

# %%
#resnet50 = models.resnet50(pretrained=True)# Pretrained on imagenet, use for clothing1m later

# %%
""" Wide Resnet """


def conv3x3(in_planes, out_planes, stride=1):
    return nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=stride, padding=1, bias=True)

def conv_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        init.xavier_uniform(m.weight, gain=np.sqrt(2))
        init.constant(m.bias, 0)
    elif classname.find('BatchNorm') != -1:
        init.constant(m.weight, 1)
        init.constant(m.bias, 0)

class wide_basic(nn.Module):
    def __init__(self, in_planes, planes, dropout_rate, stride=1):
        super(wide_basic, self).__init__()
        self.bn1 = nn.BatchNorm2d(in_planes)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, padding=1, bias=True)
        self.dropout_rate = dropout_rate
        if self.dropout_rate>0:
            self.dropout = nn.Dropout(p=dropout_rate)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=stride, padding=1, bias=True)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, bias=True),
            )

    def forward(self, x):
        out = self.conv1(F.relu(self.bn1(x)))
        if self.dropout_rate>0:
            out = self.dropout(out)
        out = self.conv2(F.relu(self.bn2(out)))
        out += self.shortcut(x)

        return out

class Wide_ResNet(nn.Module):
    def __init__(self, dropout_rate=0, depth=28, widen_factor=2, num_classes=10):
        super(Wide_ResNet, self).__init__()
        self.in_planes = 16

        assert ((depth-4)%6 ==0), 'Wide-resnet depth should be 6n+4'
        n = (depth-4)//6
        k = widen_factor

        print('| Wide-Resnet %dx%d' %(depth, k))
        nStages = [16, 16*k, 32*k, 64*k]

        self.conv1 = conv3x3(3,nStages[0])
        self.layer1 = self._wide_layer(wide_basic, nStages[1], n, dropout_rate, stride=1)
        self.layer2 = self._wide_layer(wide_basic, nStages[2], n, dropout_rate, stride=2)
        self.layer3 = self._wide_layer(wide_basic, nStages[3], n, dropout_rate, stride=2)
        self.bn1 = nn.BatchNorm2d(nStages[3], momentum=0.9)
        self.linear = nn.Linear(nStages[3], num_classes)

    def _wide_layer(self, block, planes, num_blocks, dropout_rate, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []

        for stride in strides:
            layers.append(block(self.in_planes, planes, dropout_rate, stride))
            self.in_planes = planes

        return nn.Sequential(*layers)

    def forward(self, x, get_feat=False):
        out = self.conv1(x)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = F.relu(self.bn1(out))
        out = F.avg_pool2d(out, 8)
        out = out.view(out.size(0), -1)
        
        if get_feat:
            return out
        else:
            return self.linear(out)

# %%
class NoiseNet:
  def __init__(self, name='default_net'):
    self.net = Wide_ResNet().cuda()
    self.name = name
    self.lr = 0.001
    self.optimizer = optim.SGD(self.net.parameters(), lr=self.lr, momentum=0.9, weight_decay=5e-4)
    self.hist = {'cleanloss':[], 'noisyloss':[], 'loss':[], 'test_acc':[], 'epoch':0}
    self.CE_loss = nn.CrossEntropyLoss()#F.cross_entropy()


  #saving and loading, FIX FOR WIDE RESNET
  def save_net(self, name='version_', path='/content/gdrive/MyDrive/dl_adv_proj/'):
    net_state ={'state_dict':self.net.state_dict(),'optimizer':self.optimizer.state_dict()}

    torch.save(net_state,  path+name+'net')
    torch.save(self.hist, path+name+'hist')
    print(f'saved at: {path+name}')

  def load_net(self, name='version_', path='/content/gdrive/MyDrive/dl_adv_proj/'):
    net_state  = torch.load(path+name+'net')
    self.net.load_state_dict(net_state['state_dict'])
    self.optimizer.load_state_dict(net_state['optimizer'])

    self.hist = torch.load(path+name+'hist')
    print(f'loaded from {path+name}')

  def eq1_func(self,sigma=1e-3):  
    # param_vector = parameters_to_vector(self.net.parameters())#
    # noise = sigma*torch.normal(0,1,size=param_vector.shape).cuda()
    # param_vector.add_(noise)
    # vector_to_parameters(param_vector,self.net.parameters())
    for param in self.net.parameters():
      #param.grad += sigma*torch.normal(0,1,size=param.grad.shape).cuda()
      param.grad += sigma*torch.randn_like(param.grad).cuda()

    return True

  def eq2_func(self,grad,sigma=1e-3):#loss,pred,sigma=1e-3):
    # logsoft = F.log_softmax(pred)
    # one_target = F.one_hot(target, num_classes=10)
    # presum = torch.mul(logsoft,one_target)#BEFORE SUMMING
    # #presum += sigma*torch.normal(0,1,size=presum.shape).cuda()
    # loss = -presum.sum(axis=1) #same as loss pre-reduction, checksum
    # mean = torch.mean(loss)
    #autog =  torch.autograd.grad(mean,pred)
    #print(f'mean auto grads {autog[0].shape}:{autog}')

    # loss.backward(inputs=pred,retain_graph=True)
    # pred.grad += sigma*torch.normal(0,1,size=pred.grad.shape).cuda()
    # pred.mean().backward()#torch.tensor(np.ones_like((pred.shape)),dtype=torch.float)

    #self.eq2_func(loss,pred,sigma)
    #loss.backward()
    #loss.backward(inputs=pred)
    #pred.grad += sigma*torch.normal(0,1,size=pred.grad.shape).cuda()
    #pred.backward(torch.tensor(np.ones_like((pred.shape)),dtype=torch.float))
    tensor_size = torch.numel(grad.data)
    noise = sigma*(torch.randn_like(grad.data)/np.sqrt(tensor_size)).cuda()
    #grad + sigma*torch.normal(0,1,size=grad.data.shape).cuda()
    return grad+noise

  def test_acc(self, test_dl):   
    self.net.eval()
    correct = 0
    
    with torch.no_grad():
      for data in test_dl:
        x, y = data[0].cuda(),data[1].cuda()
        output = self.net(x)
        _, predictions = torch.max(output, 1)
        for i in range(len(y)):
          if predictions[i] == y[i]:
            correct += 1 
    
    self.net.train() 

    return correct / 10000
      
  def train(self,dataloader, testdataloader, epochs,noise=True, ema=None,eq2=False,eq1=False, sigma=1e-3):
      epoch_range = tqdm(range(self.hist['epoch'],epochs))
      self.net.train()

      for epoch in epoch_range:
        total_loss = 0
        total_cleanl = 0
        total_noisyl = 0
        for i,(x,y) in enumerate(dataloader):#dataloaders give us (image,label) 

          if noise:            
            target = y[0].cuda()
            clean_indicator = y[1].cuda()
            x = x.cuda()
          else:
            x,target = x.cuda(),y.cuda()

          self.optimizer.zero_grad()
          pred = self.net(x)
          loss = F.cross_entropy(pred, target, reduction='none')

          if noise:
            clean_loss = torch.mean(torch.masked_select(loss,clean_indicator))
            noisy_loss = torch.mean(torch.masked_select(loss,~clean_indicator))
            total_cleanl += clean_loss.item()
            total_noisyl += noisy_loss.item()

          loss = torch.mean(loss)

          #eq2 has to be before loss.backward()
          if eq2: pred.register_hook(lambda grad,sigma=sigma: self.eq2_func(grad,sigma=sigma)) 
          loss.backward()

          #eq1 has to be before optimizer.step()
          if eq1: self.eq1_func(sigma)
          self.optimizer.step()

          if ema: ema.update()

          total_loss += loss.item()

          epoch_range.set_postfix({'Progress in epoch': i/390.25, ' _loss': loss.item() })
        self.hist['loss'].append(total_loss/(i+1))
        if noise:
          self.hist['cleanloss'].append(total_cleanl/(i+1))
          self.hist['noisyloss'].append(total_noisyl/(i+1))
        if (epoch % 1) == 0:
          test_acc = self.test_acc(testdataloader)
          print(test_acc)
          self.hist['test_acc'].append(test_acc)

        self.hist['epoch']+=1
    
        #self.save_net(name='--')#FOR SAVING LATER
        print(f'epoch:{epoch}')

  def instance_train(self,dataloader, testdataloader, epochs):
    epoch_range = tqdm(range(self.hist['epoch'],epochs))
    self.net.train()
    idx_pred=np.zeros((50000,10))#cifar10 train length
    for epoch in epoch_range:
      total_loss = 0
      total_cleanl = 0
      total_noisyl = 0
      for i,(x,y) in enumerate(dataloader):#dataloaders give us (image,label) 
        target = y[0].cuda()
        idx_indicator = y[1].cuda()
        x=x.cuda()

        self.optimizer.zero_grad()               

        pred = self.net(x)
        soft = F.softmax(pred)
        #print(f'log_soft:{log_soft[:2]}, \nsoft:{soft[:2]}')
        loss = F.cross_entropy(pred, target, reduce=False) 

        for i,s in enumerate(soft):
          idx_pred[idx_indicator[i]] += s.cpu().detach().numpy()

        loss = torch.sum(loss)

        #print(f'loss:{loss.item()}, clean+noise:{clean_loss.item()+noisy_loss.item()},clean:{clean_loss.item()}, noisy:{noisy_loss.item()}')

        loss.backward()
        self.optimizer.step()


        total_loss += loss.item()
        epoch_range.set_postfix({'Progress in epoch': i/390.25, ' _loss': loss.item() })
      self.hist['loss'].append(total_loss/(i+1))
      if (epoch % 5) == 0:
        test_acc = self.test_acc(testdataloader)
        print(test_acc)
        self.hist['test_acc'].append(test_acc)

      self.hist['epoch']+=1
  
      #self.save_net(name=self.name)#FOR SAVING LATER
      print(f'epoch:{epoch}')
    return idx_pred/epochs

# %%
¨testnet = NoiseNet()
#ema = ExponentialMovingAverage(testnet.net.parameters(), decay=0.999) #https://github.com/fadel/pytorch_ema
testnet.train(c10_train_dl, c10_test_dl, 10,eq1=True)
# Out:
# | Wide-Resnet 28x2
#   0%|          | 0/10 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-9eb28c88b401> in <module>()
#       1 testnet = NoiseNet()
#       2 #ema = ExponentialMovingAverage(testnet.net.parameters(), decay=0.999) #https://github.com/fadel/pytorch_ema
# ----> 3 testnet.train(c10_train_dl, c10_test_dl, 10,eq1=True)
#       4
#
# <ipython-input-9-f556361fa4c7> in train(self, dataloader, testdataloader, epochs, noise, ema, eq2, eq1, sigma)
#     116           if ema: ema.update()
#     117
# --> 118           total_loss += loss.item()
#     119
#     120           epoch_range.set_postfix({'Progress in epoch': i/390.25, ' _loss': loss.item() })
#
# KeyboardInterrupt:

# %%
torch.autograd.set_detect_anomaly(True)
